# %%
try:
    import google.colab
    # !rm -rf /content/SportWarzSim
    # !git clone https://github.com/daltontf/SportWarzSim.git 
    # %cd SportWarzSim
except ImportError:
    pass

# %%
from sportwarz import load_counties_geojson

counties_geojson = load_counties_geojson()

# %%
from sportwarz import load_counties_data

co_data_frame = load_counties_data(counties_geojson)

# %%
from sportwarz import load_leagues

leagues = {
    'MLB': {  },
}    

load_leagues(leagues)

# %%
from sportwarz import calculate_distances

calculate_distances(leagues, co_data_frame)

# %%
from sportwarz import compute_shares
        
compute_shares(leagues, co_data_frame)

# %%
from sportwarz import compute_output_dataframes

compute_output_dataframes(leagues, co_data_frame)

# %%
from sportwarz import render_map, reset_county_styles, heatmap_counties

reset_county_styles(counties_geojson)
heatmap_counties(leagues, counties_geojson, "MLB") 

render_map(leagues, "MLB", counties_geojson, co_data_frame)
# Out:
# HTML(value='\n        <style>\n        .leaflet-popup-content-wrapper {\n            background-color: black;\…
# Map(center=[38.72728229549864, -96.9010842308538], controls=(ZoomControl(options=['position', 'zoom_in_text', …

# %%
# Complete move of A's to Vegas
from sportwarz import update_team, add_team, Team, Coordinates, reset_county_styles

league_name = "MLB"    

team_LVAs = Team(
    name = "Las Vegas A's" ,
    L = 5.0,
    S = 1.0,
    venue = "Fisher's Armadillo",
    state = "Nevada",
    coordinates = Coordinates(
        lat = 36.099444,
        lon = -115.170000
))

leagues_wLAV = update_team(co_data_frame, "MLB", "Athletics", team_LVAs)

reset_county_styles(counties_geojson)
heatmap_counties(leagues_wLAV, counties_geojson, league_name) 

render_map(leagues_wLAV, league_name, counties_geojson, co_data_frame)
# Out:
# HTML(value='\n        <style>\n        .leaflet-popup-content-wrapper {\n            background-color: black;\…
# Map(center=[38.72728229549864, -96.9010842308538], controls=(ZoomControl(options=['position', 'zoom_in_text', …

# %%
from sportwarz import Team, Coordinates, league_teams_sums, add_team, reset_county_styles, heatmap_counties

league_name = "MLB"

team_SLC = Team(
    name = "Salt Lake Bees" ,
    L = 4.0,
    S = 2.0,
    venue = "Bees Knees Field",
    state = "Utah",
    color = "yellow",
    coordinates = Coordinates(
        lat =  40.5497,
        lon = -112.0225
))

leagues_MLB_wSLC = add_team(co_data_frame, league_name, [team_SLC])

reset_county_styles(counties_geojson)
heatmap_counties(leagues_MLB_wSLC, counties_geojson, league_name) 
render_map(leagues_MLB_wSLC, league_name, counties_geojson, co_data_frame)
# Out:
# HTML(value='\n        <style>\n        .leaflet-popup-content-wrapper {\n            background-color: black;\…
# Map(center=[38.72728229549864, -96.9010842308538], controls=(ZoomControl(options=['position', 'zoom_in_text', …

# %%
import pandas as pd

pd.set_option('display.float_format', lambda x: '%.3f' % x)

def show_pre_post_merged_results(league_before, league_after):
    pre_sums = league_teams_sums(league_before)
    post_sums = league_teams_sums(league_after)
    merged = pd.merge(pre_sums, post_sums, on='team_name', how='right')
    merged["share_population_x"].fillna(0, inplace = True) 
    merged["share_population_delta"] = merged["share_population_y"] - merged["share_population_x"]
    print(merged)
    print(f"Sums\t: {merged["share_population_x"].sum()}\t{merged["share_population_y"].sum()}")
    print(f"Sum Delta = {merged["share_population_y"].sum() - merged["share_population_x"].sum()}") 

show_pre_post_merged_results(
    leagues[league_name],
    leagues_MLB_wSLC[league_name], 
)
# Out:
#                        share_population_x  share_population_y  \
# team_name
# New York Yankees             28151405.284        28144314.887
# Los Angeles Dodgers          24497198.212        24364241.156
# Atlanta Braves               17773693.939        17611140.556
# Chicago Cubs                 15989245.523        15974054.568
# Houston Astros               14728118.477        14670849.132
# Cincinnati Reds              13369554.113        13317841.048
# Texas Rangers                13272435.024        13209379.497
# Boston Red Sox               12193886.375        12185424.620
# San Francisco Giants         12280530.933        12164592.074
# St. Louis Cardinals           9138146.257         9081627.092
# Seattle Mariners              9134424.849         9053134.219
# Philadelphia Phillies         8674043.499         8658874.892
# Detroit Tigers                8552004.326         8543825.060
# Tampa Bay Rays                8367823.254         8285170.182
# Miami Marlins                 7712985.079         7670075.202
# Washington Nationals          6980882.228         6927190.461
# Arizona Diamondbacks          6274481.140         6156150.763
# Minnesota Twins               6058377.997         6023843.035
# Kansas City Royals            5488576.109         5441082.494
# Baltimore Orioles             5287040.349         5258020.151
# Cleveland Guardians           5151774.306         5155414.233
# Milwaukee Brewers             4720378.157         4710129.892
# New York Mets                 3173703.890         3236431.379
# Colorado Rockies              3418967.920         3166555.287
# Pittsburgh Pirates            3074854.255         3055544.011
# Salt Lake Bees                      0.000         2652335.667
# San Diego Padres              2395895.629         2459673.074
# Toronto Blue Jays             1235747.927         1232407.394
# Chicago White Sox              168660.801          170917.719
# Los Angeles Angels             130369.569          113227.134
# Athletics                       52060.995           53518.629
#
#                        share_population_delta
# team_name
# New York Yankees                    -7090.397
# Los Angeles Dodgers               -132957.056
# Atlanta Braves                    -162553.383
# Chicago Cubs                       -15190.955
# Houston Astros                     -57269.345
# Cincinnati Reds                    -51713.065
# Texas Rangers                      -63055.527
# Boston Red Sox                      -8461.755
# San Francisco Giants              -115938.859
# St. Louis Cardinals                -56519.165
# Seattle Mariners                   -81290.630
# Philadelphia Phillies              -15168.607
# Detroit Tigers                      -8179.266
# Tampa Bay Rays                     -82653.072
# Miami Marlins                      -42909.877
# Washington Nationals               -53691.767
# Arizona Diamondbacks              -118330.377
# Minnesota Twins                    -34534.962
# Kansas City Royals                 -47493.616
# Baltimore Orioles                  -29020.198
# Cleveland Guardians                  3639.927
# Milwaukee Brewers                  -10248.265
# New York Mets                       62727.489
# Colorado Rockies                  -252412.633
# Pittsburgh Pirates                 -19310.244
# Salt Lake Bees                    2652335.667
# San Diego Padres                    63777.445
# Toronto Blue Jays                   -3340.533
# Chicago White Sox                    2256.917
# Los Angeles Angels                 -17142.434
# Athletics                            1457.634
# Sums	: 257447266.41762045	258746985.50954548
# Sum Delta = 1299719.091925025
# /tmp/ipykernel_61222/3787511772.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   merged["share_population_x"].fillna(0, inplace = True)

# %%
from sportwarz import Team, Coordinates, league_teams_sums, add_team, reset_county_styles, heatmap_counties

league_name = "MLB"

team_PDX = Team(
    name = "Portland Pickles" ,
    L = 4.0,
    S = 2.0,
    venue = "Portland Park",
    state = "Oregon",
    color = "green",
    coordinates = Coordinates(
        lat = 45.5200,
        lon = -122.6886
))

leagues_MLB_wPDX = add_team(co_data_frame, league_name, [team_PDX])

reset_county_styles(counties_geojson)
heatmap_counties(leagues_MLB_wPDX, counties_geojson, league_name) 
render_map(leagues_MLB_wPDX, league_name, counties_geojson, co_data_frame)
# Out:
# HTML(value='\n        <style>\n        .leaflet-popup-content-wrapper {\n            background-color: black;\…
# Map(center=[38.72728229549864, -96.9010842308538], controls=(ZoomControl(options=['position', 'zoom_in_text', …

# %%
show_pre_post_merged_results(
    leagues[league_name],
    leagues_MLB_wPDX[league_name], 
)
# Out:
#                        share_population_x  share_population_y  \
# team_name
# New York Yankees             28151405.284        28144314.887
# Los Angeles Dodgers          24497198.212        24492271.643
# Atlanta Braves               17773693.939        17611140.556
# Chicago Cubs                 15989245.523        15974054.585
# Houston Astros               14728118.477        14670849.393
# Cincinnati Reds              13369554.113        13317841.048
# Texas Rangers                13272435.024        13209380.847
# San Francisco Giants         12280530.933        12199940.814
# Boston Red Sox               12193886.375        12185424.620
# St. Louis Cardinals           9138146.257         9081627.097
# Philadelphia Phillies         8674043.499         8658874.892
# Detroit Tigers                8552004.326         8543825.060
# Tampa Bay Rays                8367823.254         8285170.182
# Miami Marlins                 7712985.079         7670075.202
# Seattle Mariners              9134424.849         7282041.069
# Washington Nationals          6980882.228         6927190.461
# Arizona Diamondbacks          6274481.140         6235654.818
# Minnesota Twins               6058377.997         6023843.672
# Kansas City Royals            5488576.109         5441082.692
# Baltimore Orioles             5287040.349         5258020.151
# Cleveland Guardians           5151774.306         5155414.233
# Milwaukee Brewers             4720378.157         4710129.892
# Colorado Rockies              3418967.920         3355898.307
# Portland Pickles                    0.000         3265825.525
# New York Mets                 3173703.890         3236431.379
# Pittsburgh Pirates            3074854.255         3055544.011
# San Diego Padres              2395895.629         2466469.247
# Toronto Blue Jays             1235747.927         1232407.394
# Chicago White Sox              168660.801          170917.719
# Los Angeles Angels             130369.569          128931.685
# Athletics                       52060.995           43740.352
#
#                        share_population_delta
# team_name
# New York Yankees                    -7090.397
# Los Angeles Dodgers                 -4926.569
# Atlanta Braves                    -162553.383
# Chicago Cubs                       -15190.938
# Houston Astros                     -57269.084
# Cincinnati Reds                    -51713.065
# Texas Rangers                      -63054.177
# San Francisco Giants               -80590.119
# Boston Red Sox                      -8461.755
# St. Louis Cardinals                -56519.161
# Philadelphia Phillies              -15168.607
# Detroit Tigers                      -8179.266
# Tampa Bay Rays                     -82653.072
# Miami Marlins                      -42909.877
# Seattle Mariners                 -1852383.780
# Washington Nationals               -53691.767
# Arizona Diamondbacks               -38826.322
# Minnesota Twins                    -34534.326
# Kansas City Royals                 -47493.418
# Baltimore Orioles                  -29020.198
# Cleveland Guardians                  3639.927
# Milwaukee Brewers                  -10248.265
# Colorado Rockies                   -63069.612
# Portland Pickles                  3265825.525
# New York Mets                       62727.489
# Pittsburgh Pirates                 -19310.244
# San Diego Padres                    70573.618
# Toronto Blue Jays                   -3340.533
# Chicago White Sox                    2256.917
# Los Angeles Angels                  -1437.884
# Athletics                           -8320.643
# Sums	: 257447266.4176204	258034333.43103844
# Sum Delta = 587067.0134180486
# /tmp/ipykernel_61222/3787511772.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   merged["share_population_x"].fillna(0, inplace = True)
