# %% [markdown]
# ### NBA right now

# %%
from sportwarz import Simulation

league_name = "NBA"

simulation  = Simulation()
simulation.add_league(league_name)
simulation.render_current_model(league_name)

# %% [markdown]
# ### NBA moving Grizzlies to Kansas City

# %%
simulation.update_team(league_name, "Memphis Grizzlies", {   
    "name": "Kansas City Grizzlies",
    "venue": "T-Mobile Center",
    "state": ["Missouri", "Kansas"],
    "coordinates": {
        "lat":  39.0973,
        "lon": -94.58
    }})

simulation.render_current_model(league_name)

# %%
simulation.show_comparisons(league_name)
