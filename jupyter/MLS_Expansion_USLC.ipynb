# %% [markdown]
# ### MLB right now

# %%
from sportwarz import Simulation

league_name = "MLS"

simulation  = Simulation()
simulation.add_league(league_name)
simulation.render_current_model(league_name)
# Out:
# Elapsed: 1.636875619s
# HTML(value='\n            <style>\n            .leaflet-popup-content-wrapper .leaflet-popup-tip {\n          …
# Map(center=[38.72728229549864, -96.9010842308538], controls=(ZoomControl(options=['position', 'zoom_in_text', …

# %% [markdown]
# ### MLS add eight large USL teams

# %%
from sportwarz import Team, Coordinates

simulation.add_teams(league_name, [ 
  Team(
    name = "Sacramento Republic FC",
    venue = "HeartHealth Park",
    L = 1.0,
    S = 4.0,
    N = 2.0,
    coordinates = Coordinates(lat = 38.5805, lon = -121.4964),
    color = "#8B0000",
    state = "California"
),
Team(
    name = "Indy Eleven",
    venue = "Eleven Park",
    L = 1.0,
    S = 4.0,
    N = 2.0,
    coordinates = Coordinates(lat = 39.771146, lon = -86.177880),
    color = "#000060",
    state = "Indiana"
),
Team(
    name = "San Antonio FC",
    venue = "Toyota Field",
    L = 1.0,
    S = 4.0,
    N = 2.0,
    coordinates = Coordinates(lat = 29.4705, lon = -98.5144),
    color = "#000000",
    state = "Texas"
),
Team(
    name = "Detroit City FC",
    L = 1.0,
    S = 4.0,
    N = 2.0,        
    venue = "Keyworth Stadium",
    coordinates = Coordinates(lat = 42.4135, lon = -83.0304),
    color = "#A6192E",
    state = "Michigan"
),
Team(
    name = "Phoenix Rising FC",
    venue = "Phoenix Rising Soccer Stadium",
    L = 1.0,
    S = 4.0,
    N = 2.0,
    coordinates = Coordinates(lat = 33.4480, lon = -112.0740),
    color = "#EF0000",
    state = "Arizona"
),
Team(
    name = "Pittsburgh Riverhounds SC",
    venue = "Highmark Stadium",
    L = 1.0,
    S = 4.0,
    N = 2.0,    
    coordinates = Coordinates(lat = 40.4397, lon =-80.0094),
    color = "#FFC72C",
    state = "Pennsylvania"
),
Team(
    name = "Tampa Bay Rowdies",
    venue = "Al Lang Stadium",
    L = 1.0,
    S = 4.0,
    N = 2.0,
    coordinates = Coordinates(lat = 27.77062, lon = -82.63730),
    color = "#4A8B2C",
    state = "Florida"
),
Team(
    name = "Oakland Roots SC",
    venue = "Oakland Coliseum",
    L = 1.0,
    S = 4.0,
    N = 2.0,
    coordinates = Coordinates(lat = 37.7529, lon = -122.2005),
    color = "#000000",
    state = "California"
)
])

simulation.render_current_model(league_name)
# Out:
# Elapsed: 1.879191664s
# HTML(value='\n            <style>\n            .leaflet-popup-content-wrapper .leaflet-popup-tip {\n          …
# Map(center=[38.72728229549864, -96.9010842308538], controls=(ZoomControl(options=['position', 'zoom_in_text', …

# %%
simulation.show_comparisons(league_name)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_e2e8ff3c_9ad2_4cfa_b1eb_21c59ed757a1">
#   <tbody>
#     <tr>
#       <td style="vertical-align:middle; text-align:left"><a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#         Loading ITables v2.8.0 from the internet...
#         (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)
#       </td>
#     </tr>
#   </tbody>
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.5.4/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.5.4/dt_bundle.js';
#
#     document.querySelectorAll("#itables_e2e8ff3c_9ad2_4cfa_b1eb_21c59ed757a1:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {
#           "classes": ["display", "nowrap", "compact"],
#           "data_json": "[[\
47,578\"], [\"New England Revolution\", \"10,170,888\", \"331,266\", \"8,204,286\", \"279,360\", \"-1,966,602\", \"-51,906\"], [\"Real Salt Lake\", \"9,236,431\", \"312,072\", \"7,437,783\", \"264,331\", \"-1,798,647\", \"-47,741\"], [\"Seattle Sounders FC\", \"10,949,948\", \"213,418\", \"8,946,517\", \"189,076\", \"-2,003,431\", \"-24,342\"], [\"Sporting Kansas City\", \"9,708,905\", \"191,149\", \"7,841,824\", \"165,466\", \"-1,867,080\", \"-25,682\"], [\"Sacramento Republic FC\", \"0\", \"0\", \"7,360,619\", \"155,505\", \"7,360,619\", \"155,505\"], [\"Portland Timbers\", \"9,523,681\", \"156,650\", \"7,681,520\", \"133,659\", \"-1,842,161\", \"-22,991\"], [\"Detroit City FC\", \"0\", \"0\", \"7,415,733\", \"104,812\", \"7,415,733\", \"104,812\"], [\"Oakland Roots SC\", \"0\", \"0\", \"7,316,624\", \"94,849\", \"7,316,624\", \"94,849\"], [\"Tampa Bay Rowdies\", \"0\", \"0\", \"7,255,859\", \"93,131\", \"7,255,859\", \"93,131\"], [\"San Diego FC\", \"9,605,006\", \"73,701\", \"7,754,441\", \"62,425\", \"-1,850,565\", \"-11,276\"], [\"LA Galaxy\", \"10,862,154\", \"62,944\", \"8,910,261\", \"56,919\", \"-1,951,893\", \"-6,025\"], [\"Phoenix Rising FC\", \"0\", \"0\", \"7,223,200\", \"41,549\", \"7,223,200\", \"41,549\"], [\"Toronto FC\", \"8,633,523\", \"0\", \"6,933,780\", \"0\", \"-1,699,743\", \"-0\"], [\"CF Montr\\u00e9al\", \"8,628,287\", \"0\", \"6,929,713\", \"0\", \"-1,698,573\", \"-0\"], [\"Vancouver Whitecaps FC\", \"8,626,358\", \"0\", \"6,928,201\", \ ...
#           "layout": {"bottomEnd": "paging", "bottomStart": "info", "topEnd": "search", "topStart": "pageLength"},
#           "order": [],
#           "pageLength": 100,
#           "paging": false,
#           "style": {"caption-side": "bottom", "margin": "auto", "table-layout": "auto", "width":
# <!--| quarto-html-table-processing: none -->
# <table id="itables_2e7e55e3_4cdf_4187_8bf6_b5a684bb9006">
#   <tbody>
#     <tr>
#       <td style="vertical-align:middle; text-align:left"><a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#         Loading ITables v2.8.0 from the internet...
#         (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)
#       </td>
#     </tr>
#   </tbody>
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.5.4/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.5.4/dt_bundle.js';
#
#     document.querySelectorAll("#itables_2e7e55e3_4cdf_4187_8bf6_b5a684bb9006:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {
#           "classes": ["display", "nowrap", "compact"],
#           "data_json": "[[\"18,077,401\", \"19,737,987\", \"1,660,586\"]]",
#           "layout": {"bottomEnd": null, "bottomStart": null, "topEnd": null, "topStart": null},
#           "order": [],
#           "style": {"caption-side": "bottom", "margin": "auto", "table-layout": "auto", "width": "auto"},
#           "table_html": "<table><thead>\n<tr style=\"text-align: right;\">\n\n<th>Total Population Value Before</th><th>Total Population Value After</th><th>Total Population Value Change</th>\n</tr>\n<tr><th><small class='itables-dtype'>str</small></th><th><small class='itables-dtype'>str</small></th><th><small class='itables-dtype'>str</small></th></tr></thead></table>",
#           "text_in_header_can_be_selected": true
#         };
#         new ITable(table, dt_args);
#     });
# </script>
