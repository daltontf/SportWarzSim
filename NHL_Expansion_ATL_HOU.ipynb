# %% [markdown]
# ### NHL right now

# %%
from sportwarz import Simulation

league_name = "NHL"

simulation  = Simulation()
simulation.add_league(league_name)
simulation.render_current_model(league_name)

# %% [markdown]
# ### NHL adding Houston and Atlanta (again)

# %%
from sportwarz import Team, Coordinates 

simulation.add_teams(league_name, [   
   Team(
    name = "Houston Aeros" ,
    L = 2.0,
    S = 3.0,
    N = 3.0,
    venue = "Toyota Center",
    state = "Texas",
    color = "darkgreen",
    coordinates = Coordinates(
        lat = 29.750833,
        lon = -95.362222
)),Team(
    name = "Atlanta Thrashers" ,
    L = 2.0,
    S = 3.0,
    N = 3.0,
    venue = "State Farm Arena",
    state = "Georgia",
    color = "darkorange",
    coordinates = Coordinates(
        lat = 33.757290,
        lon = -84.397331
))])

simulation.render_current_model(league_name)

# %%
simulation.show_comparisons(league_name)
