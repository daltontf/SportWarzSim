# %% [markdown]
# ### NBA right now

# %%
from sportwarz import Simulation

league_name = "NBA"

simulation  = Simulation()
simulation.add_league(league_name)
simulation.render_current_model(league_name)

# %% [markdown]
# ### NBA adding San Diego

# %%
simulation.add_teams(league_name, [{   
    "name": "San Diego Conquistadors",
    "L": 1.0,
    "S": 4.0,
    "N": 3.0,
    "venue":"Pechanga Arena 2.0",
    "coordinates":{"lat":32.784000,"lon":-117.092500},
    "color":"#FFC62C",
    "state":"California"
    }])

simulation.render_current_model(league_name)

# %%
simulation.show_comparisons(league_name)
